# %%
# Out:
# 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

# %%
from openai import OpenAI
from dotenv import load_dotenv
import os
from playsound import playsound
from IPython.display import Audio
import requests
import base64
import os

# %%
load_dotenv()
api_key = os.getenv("OPENAI_API_KEY")
client = OpenAI(
    api_key=api_key
)

print(client.api_key)
# Out:
# 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

# %%
# GPT에게 첫 번째 질문을 보냅니다
response = client.chat.completions.create(
    model="gpt-4o-mini",          # 사용할 모델
    messages=[
        {"role": "system", "content": "당신은 친절한 AI 어시스턴트입니다."},
        {"role": "user",   "content": "파인튜닝이 무엇인지 한 문장으로 설명해 주세요."}
    ],
    temperature=0.7,   # 창의성 수준 (0~2, 높을수록 다양한 답변)
    max_tokens=512,    # 최대 응답 길이
)

# GPT의 답변만 뽑아서 출력
print(response.choices[0].message.content)
# Out:
# 파인튜닝은 사전 훈련된 모델을 특정 작업이나 데이터셋에 맞게 추가로 학습시켜 성능을 개선하는 과정입니다.

# %%
# ① system 없이 질문
response_no_sys = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "user", "content": "계약 해지 통보는 언제 해야 하나요?"}
    ],
    temperature=0.3,
    max_tokens=200,
)

# ② system 있이 질문
response_with_sys = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": "당신은 대한민국 법률 전문가입니다. 관련 법조항을 인용하여 3문장 이내로 답변하세요."},
        {"role": "user",   "content": "계약 해지 통보는 언제 해야 하나요?"}
    ],
    temperature=0.7,    # 창의성 수준, 높을 수록 다양한 답변
    max_tokens=512,     # 최대 응답길이
    stream = True,      # 응답을 한자씩 해줌
)

print("─── system 없음 ───")
print(response_no_sys.choices[0].message.content)

print("\n─── system 있음 ───")
print(response_with_sys.choices[0].message.content)
# Out:
# ─── system 없음 ───
# 계약 해지 통보는 계약서에 명시된 조건과 절차에 따라 진행해야 합니다. 일반적으로 다음과 같은 사항을 고려해야 합니다:
#
# 1. **계약서 확인**: 계약서에 해지 통보를 위한 특정 기간이나 절차가 명시되어 있을 수 있습니다. 이를 반드시 확인해야 합니다.
#
# 2. **법적 요건**: 계약 해지에 대한 법적 요건이 있을 수 있으므로, 관련 법률을 검토하는 것이 중요합니다.
#
# 3. **상대방 통보**: 계약 해지를 원할 경우, 상대방에게 서면으로 통보하는 것이 좋습니다. 이때 통보 시점은 계약서에 명시된 해지 통보 기간을 고려해야 합니다.
#
# 4. **사유 명시**: 해지 사유가 있는 경우, 이를 명확히 하고 상대방에게 설명하는 것이 좋습니다.
#
# 5. **기한 준수**: 해
#
# ─── system 있음 ───
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 27
#      23 print("─── system 없음 ───")
#      24 print(response_no_sys.choices[0].message.content)
#      25
#      26 print("\n─── system 있음 ───")
# ---> 27 print(response_with_sys.choices[0].message.content)
#
# AttributeError: 'Stream' object has no attribute 'choices'

# %%
# 앞에서 받은 response 를 해부해봅니다
print("📝 답변 내용:")
print(response.choices[0].message.content)   # 실제 답변

print("\n🏁 종료 이유:", response.choices[0].finish_reason)  # stop / length

print("\n📊 토큰 사용량:")
print("   입력 토큰:", response.usage.prompt_tokens)
print("   출력 토큰:", response.usage.completion_tokens)
print("   전체 토큰:", response.usage.total_tokens)
# Out:
# 📝 답변 내용:
# 파인튜닝은 사전 훈련된 모델을 특정 작업이나 데이터셋에 맞게 추가로 학습시켜 성능을 개선하는 과정입니다.
#
# 🏁 종료 이유: stop
#
# 📊 토큰 사용량:
#    입력 토큰: 40
#    출력 토큰: 36
#    전체 토큰: 76

# %% [markdown]
# 🚦 finish_reason 이란?

# %% [markdown]
# | 값 | 의미  | 대응 방법 |
# | --- | --- | --- |
# | stop | 정상 종료 | 그대로 사용 |
# | length | `max_tokens` 초과로 잘림 | `max_tokens` 값 늘리기 |
# | content_filter | 안전 정책에 걸림 | 프롬프트 수정 |

# %% [markdown]
# > ⚠️ `length` 가 뜨면 답변이 중간에 잘린 겁니다.
# > 특히 JSON 형식 응답이 잘리면 파싱 오류가 납니다!

# %%
# 🧪 실험: max_tokens 를 너무 작게 하면 어떻게 될까?
response_short = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "user", "content": "대한민국 헌법의 기본 원리를 상세히 설명해 주세요."}
    ],
    max_tokens=20,   # 의도적으로 아주 짧게 설정
)

print("답변:", response_short.choices[0].message.content)
print("종료 이유:", response_short.choices[0].finish_reason)  # → "length"
print("→ 문장이 중간에 잘렸습니다! max_tokens를 늘려야 합니다.")
# Out:
# 답변: 대한민국 헌법의 기본 원리는 민주주의, 법치주의, 인권 존중
# 종료 이유: length
# → 문장이 중간에 잘렸습니다! max_tokens를 늘려야 합니다.

# %%
response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": "당신은 친절한 AI 어시스턴트입니다."},
        {"role": "user",   "content": "계약 해지 통보는 언제 해야 하나요?"}
    ],
    temperature=0.7,    # 창의성 수준, 높을 수록 다양한 답변
    n=2,
)

print(response.choices[0].message.content)
# Out:
# 계약 해지 통보는 계약서에 명시된 해지 조건과 절차에 따라 다릅니다. 일반적으로 다음과 같은 사항을 고려해야 합니다:
#
# 1. **계약서 확인**: 계약서에 해지 통보를 위한 특정 기한이나 형식이 명시되어 있을 수 있습니다. 이를 반드시 확인해야 합니다.
#
# 2. **법적 요건**: 특정 계약의 경우, 법적으로 요구되는 해지 통보 기간이 있을 수 있습니다. 예를 들어, 임대 계약의 경우 통상 1개월 이상의 사전 통보가 필요할 수 있습니다.
#
# 3. **상대방과의 관계**: 계약 해지 통보는 상대방과의 관계에 따라 신중하게 결정해야 합니다. 가능한 한 원만한 해결을 위해 충분한 시간을 두고 통보하는 것이 좋습니다.
#
# 4. **해지 사유**: 해지 사유에 따라 통보 시점이 달라질 수 있습니다. 예를 들어, 계약 위반이 발생한 경우 즉시 통보할 수 있지만, 일반적인 사유로 해지를 원할 경우 사전 통보가 필요할 수 있습니다.
#
# 결론적으로, 계약 해지 통보는 계약서의 조건과 상황에 따라 적절한 시점에 진행하는 것이 중요합니다. 필요시 법률 전문가의 조언을 받는 것도 좋은 방법입니다.

# %%
fp = open('data/audio/베트남여행.mp3','rb')

transcriptions = client.audio.transcriptions.create(model='whisper-1',file=fp)
print(transcriptions)
print(transcriptions.text)
# Out:
# Transcription(text='베트남 여행 준비물 30초로 정리하세요. 첫 번째, 100달러 지폐입니다. 달러 금액별로 다르게 환전해주는데 큰 금액의 달러를 더 잘 쳐줍니다. 두 번째, 트래블 월레카드. 트래블 월레카드를 이용하면 환전 수수료를 100% 우대해주고 베트남 BP뱅크 ATM을 이용하면 인출 수수료도 무료라는 사실! 바로 환전할 수 있어서 편합니다. 세 번째, 동지갑. 저는 만들기 귀찮아서 샀는데요. 워낙 지폐 종류가 많다 보니 이렇게 구분되어 있는 지갑을 가져가시는 걸 추천드립니다. 네 번째, 멀티템. 보조배터리, 미니 선풍기, 휴대폰 등등등 충전할 전자기기가 너무 많죠? 멀티템 챙겨가시면 편합니다. 참고로 베트남은 대부분 220V 쓰니까 변화기는 필요 없습니다. 마지막으로 과도랑 포크. 망고 사드실 거면 챙겨가세요. 기내에는 못 들고 타는 거 아시죠? 꼭 위탁수화물에 붙이세요. 나머지는 댓글에 상세히 남겨두겠습니다. 구독하고 여행 꿀팁, 맛집 정보 받아보세요.', languages=None, logprobs=None, usage=UsageDuration(seconds=52.0, type='duration'))
# ...

# %%
fp = open('data/audio/베트남여행.mp3','rb')

transcriptions = client.audio.transcriptions.create(file=fp, model='whisper-1')
print(transcriptions.text)

summary = clinet.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": "You are summarize pro"},
        {"role": "user","content": f"please summarize th following:\n{transcription.text}"}
    ]
)
print(summary.choices[0].message.content)
# Out:
# 베트남 여행 준비물 30초로 정리하세요. 첫 번째, 100달러 지폐입니다. 달러 금액별로 다르게 환전해주는데 큰 금액의 달러를 더 잘 쳐줍니다. 두 번째, 트래블 월레카드. 트래블 월레카드를 이용하면 환전 수수료를 100% 우대해주고 베트남 BP뱅크 ATM을 이용하면 인출 수수료도 무료라는 사실! 바로 환전할 수 있어서 편합니다. 세 번째, 동지갑. 저는 만들기 귀찮아서 샀는데요. 워낙 지폐 종류가 많다 보니 이렇게 구분되어 있는 지갑을 가져가시는 걸 추천드립니다. 네 번째, 멀티템. 보조배터리, 미니 선풍기, 휴대폰 등등등 충전할 전자기기가 너무 많죠? 멀티템 챙겨가시면 편합니다. 참고로 베트남은 대부분 220V 쓰니까 변화기는 필요 없습니다. 마지막으로 과도랑 포크. 망고 사드실 거면 챙겨가세요. 기내에는 못 들고 타는 거 아시죠? 꼭 위탁수화물에 붙이세요. 나머지는 댓글에 상세히 남겨두겠습니다. 구독하고 여행 꿀팁, 맛집 정보 받아보세요.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 6
#       2
#       3 transcriptions = client.audio.transcriptions.create(file=fp, model='whisper-1')
#       4 print(transcriptions.text)
#       5
# ----> 6 summary = clint.chat.completions.create(
#       7     model="gpt-4o-mini",
#       8     messages=[
#       9         {"role": "system", "content": "You are summarize pro"},
#
# ...

# %%
summary = client.chat.completions.create(
    model='gpt-4o-mini',
    messages=[
        { 'role': 'system', 'content': 'You are summarize pro' },
        { 'role': 'user', 'content': f'Please summarize the following: \n{transcriptions.text}' },
    ]
)

print(summary.choices[0].message.content)
# Out:
# 베트남 여행 준비물로는 다음이 있습니다. 첫째, 100달러 지폐는 환전 시 유리합니다. 둘째, 트래블 월레카드로 환전 수수료를 100% 우대받고, 베트남 BP뱅크 ATM에서 무료 인출이 가능합니다. 셋째, 다양한 지폐를 구분할 동 지갑을 추천합니다. 넷째, 보조배터리, 미니 선풍기 등 전자기기를 충전할 수 있는 멀티템을 챙기세요, 한국은 220V를 사용하므로 변압기는 필요 없습니다. 마지막으로 망고를 사기 위해 과도와 포크를 위탁수화물에 꼭 넣으세요. 추가 정보는 댓글에 남겨둡니다. 구독하면 여행 꿀팁과 맛집 정보를 받을 수 있습니다.

# %%
def transcribe_audio(file_path) :
    fp = open(file_path, 'rb')
    transcription = client.audio.transcription.create(file=fp, model='whisper-1')

    fp.close()
    return trascription.text

def transcribe_and_summarize(trascription_text):
    response = client.chat.completions.create(model='gpt-4o-mini',
    messages=[
        { 'role': 'system', 'content': 'You helpful assistant that summarizes text' },
        { 'role': 'user', 'content' :f'다음 내용을 간단히 요약해줘: \n{transcription.text}' }
    ])
    return response.choices[0].message.content

transcription_text = transcribe_audio( 'data/audio/베트남여행.mp3')
print('오디오로부터 추출된 텍스트:',trascription_text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 16
#      12         { 'role': 'user', 'content' :f'다음 내용을 간단히 요약해줘: \n{transcription.text}' }
#      13     ])
#      14     return response.choices[0].message.content
#      15
# ---> 16 transcription_text = transcribe_audio( 'data/audio/베트남여행.mp3')
#      17 print('오디오로부터 추출된 텍스트:',trascription_text)
#
# Cell In[22], line 3, in transcribe_audio(file_path)
#       1 def transcribe_audio(file_path) :
#       2     fp = open(file_path, 'rb')
# ----> 3     transcription = client.audio.transcription.create(file=fp, model='whisper-1')
#       4
#       5     fp.close()
#       6     return trascription.text
#
# AttributeError: 'Audio' object has no attribute 'transcription'

# %%
response = client.audio.speech.create(input='퇴근하겠습니다~', model='tts-1',voice='nova')

print(response)
#1 권장 방식 : SDK 내장 메서드 사용
# resopnse.write_to_file("output/out.mp3")
# 이 위에줄도 돌리면 두배로 토큰이 빠지나?

#open() 사용 시 방식
with open('output/out.mp3','wb') as fp:
    fp.write(response.read())

# %%
prompt = input('prompt:')

response = client.chat.completions.create(
    model='gpt-4o-mini',
    messages=[
        {'role': 'user','content': prompt}
    ]
)

resp = response.choices[0].message.content
print('gpt',resp)

response_to_voice = client.audio.speech.create(input=resp, model='tts-1',voice='nova')
with open('output/sound2.mp3', 'wb') as fp:
    fp.write(response_to_voice.content)

Audio('output/sound2.mp3',autoplay=True)
# Out:
# gpt 안녕하세요! 힘세고 강한 아침입니다. 오늘 하루도 힘차게 시작하세요! 어떤 도움을 드릴까요?
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
response = client.images.generate(
    prompt="A scene of Elon Musk traveling to Mars aboard a SpaceX spacecraft.",
    model="gpt-image-1",
    size="1024x1024",
    quality="high"
)

image_data = base64.b64decode(response.data[0].b64_json)
os.makedirs("output", exist_ok=True)
with open("output/elon_musk_mars.png", "wb") as f:
    f.write(image_data)

print("Image saved as output/elon_musk_mars.png")
# Out:
# Image saved as output/elon_musk_mars.png

# %%
def encode_image(image_path):
    with open(image_path,"rb") as f:
        return base64.b64encode(f.read()).decode("utf-8")
image_base64 = encode_image("data/image/명함.png")          # 여기 본인의 로컬 이미지 경로

data_url = f"data:image/png;base64,{image_base64}"

response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[{
            "role":"user","content" :[
                {"type": "text","text": "이미지의 글자 추출해 줄래"},
                {"type":"image_url","image_url":{"url":data_url}},
            ],
        }]
)
print(response.choices[0].message.content)
# Out:
# 다음은 이미지에서 추출한 글자입니다.
#
# ---
#
# **수협중앙회**
#
# 홍 길 동
# 서울지점 / 지점장
#
# 123-456 서울특별시 00구 00로 서울빌딩
# Tel 02-2000-0000
# Fax 02-2000-0000
# phone 010-0000-0000
# email seoul@suhyup.com
#
# [www.suhyup.co.kr](http://www.suhyup.co.kr)
#
# ---
#
# **- 수협 명함 A형 -**

# %%
url = "https://pixabay.com/ko/images/download/chathuraanuradha-animals-7696695_1920.jpg"
headers = {"User-Agent": "Mozilla/5.0"}
img_response = requests.get(url,headers=headers)

base64_image = base64.b64encode(img_response.content).decode("utf-8")

prompt =[{ 
     "role":"user","content" :[
                {"type": "text","text": "이 이미지에 대해 설명해줘"},
                {"type":"image_url","image_url":{"url":f"image/jpeg;base64,{base64_image}"
                },
            },
        ],
    }
]
