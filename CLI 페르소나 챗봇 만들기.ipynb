# %% [markdown]
# # 🎯  실습: CLI 페르소나 챗봇 만들기
#
# ## 📋 실습 흐름
#
# 실무에서 챗봇을 처음 만들 때 거치는 5단계를 그대로 따라갑니다.
#
# ```
# Step 0. 초기 설정          ← 패키지 설치, API 키 설정 (Colab/로컬 공통)
# Step 1. 환경 점검          ← 1·2교시 코드가 정상 동작하는지 확인
# Step 2. 페르소나 설계       ← 1단계+2단계 (요구사항·system 메시지)
# Step 3. 챗봇 함수 만들기    ← 3단계 (MVP, prompt | llm)
# Step 4. 명령어 처리        ← 4단계 (인터랙션)
# Step 5. CLI 대화 루프      ← 4단계 (완성)
# Step 6. 시연 시나리오 검증  ← 5단계
# Step 7. 도전 과제          ← 실무 확장
# ```
#
# ## ⚠️ 시작 전 확인
#
# - [ ] OpenAI API 키가 준비되어 있음 (https://platform.openai.com/api-keys)
#
#
# 준비 됐으면 시작합시다!

# %% [markdown]
# ---
#
# # Step 0. 초기 설정
#
# ## 0-1. 패키지 설치
#
# LangChain 관련 패키지를 설치합니다.
#
# - `langchain` : LangChain 메인 패키지
# - `langchain-openai` : OpenAI 모델 연동
# - `python-dotenv` : `.env` 파일 로드용
#
# > 💡 이미 설치된 환경이라면 그대로 통과되므로 그냥 실행하세요.

# %%
# 패키지 설치 
#!uv add  langchain langchain-openai python-dotenv

# %% [markdown]
# ## 0-2. OpenAI API 키 설정
#
# API 키를 환경변수에 등록합니다. 다음 우선순위로 동작합니다.
#
# 1. **로컬 `.env` 파일** — `OPENAI_API_KEY=sk-...` 형태로 적혀 있으면 자동 로드
# 2. **이미 환경변수에 등록되어 있으면** — 그대로 사용
#
# > ⚠️ API 키는 **절대 코드에 직접 적지 마세요**. 노트북을 공유하면 그대로 노출됩니다.

# %% [markdown]
# ---
#
# # Step 1. 환경 점검
#
# ## 1-1. 필요한 패키지 import
#
#
#
# | 도구 | 역할 | 어디서 배웠나 |
# | --- | --- | --- |
# | `ChatOpenAI` | LangChain의 OpenAI 모델 클래스 | ① Models |
# | `ChatPromptTemplate` | 프롬프트 템플릿 |  ② Prompts |

# %%
# 패키지 import
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate

print("✅ import 완료")
# Out:
# ✅ import 완료

# %% [markdown]
# ## 1-2. 2교시 기본 패턴이 동작하는지 확인
#
# 오늘 챗봇의 뼈대가 되는 `prompt | llm` 패턴을 한 번 돌려봅시다.
#
# > 💡 만약 여기서 에러가 나면 챗봇을 만들 수 없습니다. 먼저 환경 문제부터 해결하세요.

# %%
# 2교시에서 배운 기본 패턴
llm = ChatOpenAI(model="gpt-5-nano", temperature=0.3)

prompt = ChatPromptTemplate.from_messages([
    ("system", "당신은 {role}입니다."),
    ("human", "{question}")
])

chain = prompt | llm   # LCEL 파이프 연산자 

# 동작 확인
result = chain.invoke({"role": "데이터 분석가", "question": "이상치란 무엇인가요? 한 문장으로."})
print(result.content)
# Out:
# 이상치는 데이터 분포에서 다른 관측값들과 현저하게 차이가 나며, 모델의 추정이나 분석에 영향을 주거나 왜곡을 일으킬 수 있는 관측값이다.

# %% [markdown]
# **✅ 결과 확인**
#
# 분석가 톤의 한 문장 답변이 출력되면 환경 OK입니다.
#
# 에러가 나면:
# - `AuthenticationError` → Step 0-2 다시 실행해서 API 키 재입력
# - `ModuleNotFoundError` → Step 0-1 다시 실행 후 커널 재시작

# %% [markdown]
# ---
#
# # Step 2. 페르소나 설계 (실무 5단계 중 1·2단계)
#
# ## 2-1. 왜 페르소나를 먼저 설계하나?
#
#  **system 메시지 한 줄로 LLM의 답변 톤이 완전히 바뀝니다.**
#
# 실무 챗봇 구축에서 가장 먼저 정해야 하는 것이 바로 "이 챗봇이 누구인가"입니다. 페르소나가 흔들리면 답변 톤이 흔들리고, 답변 톤이 흔들리면 사용자가 떠납니다.
#
# ## 2-2. 페르소나 사전 만들기
#
# 5가지 페르소나를 Python 사전(dict)으로 정의합니다. **key는 페르소나 이름, value는 system 메시지**예요.

# %%
# 페르소나 사전: 이름 → system 메시지
PERSONAS = {
    "분석가": "당신은 10년 차 데이터 분석가입니다. 수치와 근거를 들어 간결하게 답변하세요.",
    "마케터": "당신은 디지털 마케팅 전문가입니다. 비즈니스 관점과 사례를 들어 답변하세요.",
    "개발자": "당신은 시니어 백엔드 개발자입니다. 코드 예시와 함께 실용적으로 답변하세요.",
    "기획자": "당신은 IT 서비스 기획자입니다. 사용자 가치와 우선순위 관점에서 답변하세요.",
    "디자이너": "당신은 UX 디자이너입니다. 사용자 경험과 시각적 비유로 쉽게 답변하세요.",
}

print(f"✅ {len(PERSONAS)}개 페르소나 등록 완료: {list(PERSONAS.keys())}")

# 그런데 이 페르소나를 이렇게 간단하게 해야 하는가
# Out:
# ✅ 5개 페르소나 등록 완료: ['분석가', '마케터', '개발자', '기획자', '디자이너']

# %% [markdown]
# ## 2-3. 페르소나 차이 확인
#
# 같은 질문에 페르소나별로 답변이 어떻게 달라지는지 직접 확인해봅시다.

# %%
# 같은 질문, 다른 페르소나
question = "좋은 데이터란 무엇인가요?"

for name in ["분석가", "마케터"]:
    result = chain.invoke({"role": PERSONAS[name], "question": question})
    print(f"\n[{name}]")
    print(result.content)
    print("-" * 60)
# Out:
# [분석가]
# 좋은 데이터란 목적에 맞춰 의사결정을 신뢰하게 만드는 데이터입니다. 핵심은 특정 용도에서 필요한 품질 속성을 충족하는지 여부입니다.
#
# 주요 품질 차원과 측정 예시
# - 정확도(accuracy): 실제 값과 일치 여부. 예: 1,000건 중 20건 오차 → 98% 정확도.
# - 완전성(completeness): 필수 필드 누락 여부. 예: 누락 비율 3% → 97% 완전성.
# - 일관성(consistency): 서로 다른 소스 간 값 불일치 비율. 예: 5% 불일치.
# - 최신성/timeliness: 데이터가 의도한 시점에 신선한지. 예: SLA 24시간 내 갱신 달성 여부.
# - 유효성(validity): 형식/비즈니스 규칙 준수. 예: 이메일 형식 99% 유효.
# - 중복성(duplication): 중복 레코드 비율. 예: 중복 0.5%.
# - 관련성(relevance): 분석 목적에 필요한 변수/필드 보유 여부. 예: 커버리지 95% 이상.
# - 추적성/거버넌스( lineage/traceability): 출처와 변환 이력 확보 여부.
# - 접근성/가용성(accessibility): 필요 시점에 이용 가능 여부, 보안과 성능 고려.
#
# 측정 및 관리 방법
# - 데이터 프로파일링: 샘플링으로 각 차원의 현재 상태를 빠르게 진단.
# - 규칙 정의: 값의 형식, 범위, 관계 등 검증 규칙 작성.
# - 데이터 거버넌스: 책임자(데이터 책임자), 표준, 정책 확정.
# - 자동화 검사: 수집/저장 파이프라인에 유효성·완전성 검사 포함.
# - 모니터링 및 경보: 품질 지표가 임계치를 벗어나면 알림.
# - 개선 우선순위: 영향도와 비용을 기준으로 정렬하여 개선.
#
# 간단한 품질 점수 예
# - 점수 방식: 각 차원에 가중치를 부여하고 0-100점으로 합산
#   예) 정확도 0.25, 완전성 0.20, 일관성 0.15, 최신성 0.15, 유효성 0.15, 중복성 0.10
#   각 차원에서 현재 점수 0-100을 얻으면 전체 점수 = 가중합
# - 이 방식으로 현재 데이터의 상태를 수치로 관리하고, 목표치와의 격차를 우선순위로 정리.
#
# 실무 팁
# - 용도별로 대상을 쪼개 관리: 마케팅 프로파일링과 운영 데이터는 품질 요구가 다릅니다.
# - 필수 필드는 항상 높은 완전성 목표: 예를 들어 고객식별자, 연락처 등은 99% 이상.
# - 데이터 출처와 변환을 문서화: 데이터 라인리지가 있으면 재현성과 책임소재가 명확해짐.
# - 초기 목표는 간단하게 시작하고, 점진적 개선으로 확장: 예를 들어 먼저 정확도와 누락률 개선부터.
#
# 짧은 결론
# 좋은 데이터는 특정 의사결정을 뒷받침하기에 충분히 정확하고, 완전하며, 일관적이고, 최신이며, 중복 없이, 쉽게 찾고 검증할 수 있는 데이터입니다. 측정 가능하고 관리 가능한 품질 관리 체계를 갖추는 것이 핵심입니다. 필요하신 용도나 데이터 유형을 알려주면 더 구체적인 품질 지표와 목표치를 함께 제시해 드리겠습니다.
# ------------------------------------------------------------
#
# [마케터]
# 좋은 데이터란 무엇인가요? 비즈니스 관점에서 본 정의와 실무 사례를 정리해 드립니다.
#
# 1) 좋은 데이터의 정의
# - 목적지향성: 비즈니스 목표를 달성하는 데 직접 활용될 수 있는 데이터
# - 신뢰성: 수집·처리 과정이 검증 가능하고 오류가 적은 데이터
# - 적시성: 필요한 시점에 필요한 형태로 제공되어 의사결정을 뒷받침하는 데이터
# - 완전성: 필요한 모든 필드가 존재하고 누락이 최소화된 데이터
# - 일관성: 같은 규칙과 형식으로 일관되게 관리되어 다른 시스템 간에도 모순이 없는 데이터
# - 가용성: 필요한 사람이나 시스템이 쉽게 접근하고 사용할 수 있는 포맷과 API를 갖춘 데이터
# - 보안·프라이버시 준수: 개인정보 보호 규정과 내부 정책을 준수하는 데이터
#
# 2) 좋은 데이터를 만드는 7가지 핵심 특징
# - 관련성: 현재 마케팅 목표(리드 생성, 전환, 재구매 등)에 직접 연관된 속성과 이벤트 only 포함
# - 정확성: 값이 실제 현황과 맞아떨어지고 오류가 최소화
# - 완전성: 필수 필드(예: 이메일, 위치, 구매 이력 등)가 누락되지 않도록 구성
# - 시의성: 최신 상태로 업데이트되며, 과거 데이터도 필요 시점에 따라 보정 가능
# - 일관성: 단위, 포맷, 코드/분류 체계가 시스템 간에 동일하게 유지
# - 중복 제거: 동일한 고객이 여러 번 기록되지 않도록 식별자 매칭이 정확
# - 접근성: 분석가나 마케터가 쉽게 조회·추출·코드화하여 사용할 수 있는 구조
#
# 3) 왜 중요한가? 비즈니스 가치
# - 타깃 정확도 향상: 좋은 데이터로 세그먼트가 더 정밀해져 클릭률, 도달율, 전환율이 향상
# - 실험 신뢰도 증가: 데이터 품질이 높으면 A/B 테스트의 통계적 파워가 커져 의사결정 속도와 신뢰도 증가
# - ROI 개선: 잘 정의된 데이터로 마케팅 예산을 효과적으로 배분하고 중복 지출을 줄일 수 있음
# - 고객 경험 강화: 개인화된 메시지와 흐름이 가능해져 재방문 및 재구매를 촉진
# - 정확한 어트리뷰션: 채널 간 기여도를 더 신뢰성 있게 측정해 마케터의 의사결정이 합리화
#
# 4) 실무 사례(비즈니스 사례 중심)
# - 사례 1: 전자상거래 브랜드의 이메일 마케팅
#   - 상황: 고객 프로필, 구매 이력, 관심사, 행동 이벤트를 한 곳에서 관리하는 CRM이 부재한 상태
#   - 개입: 데이터 표준화와 중복 제거, 필수 필드 확정, 이벤트 트리거를 기반으로 한 세그먼트 구축
#   - 성과: 이메일 오픈율이 25%에서 32%로 상승, 클릭률이 4%에서 6%로 증가, 특정 세그먼트의 매출 기여도 증가
# - 사례 2: SaaS 스타트업의 온보딩 효율
#   - 상황: 제품 사용 데이터를 통합하지 못해 activation 포인트가 불명확
#   - 개입: 핵심 활성화 이벤트 정의(예: 7일 이내 특정 기능 3회 사용), 코호트 분석으로 온보딩 흐름 최적화
#   - 성과: 활성화율이 25%에서 40%로 증가, 30일 이탈률이 감소하고 LTV가 상승
# - 사례 3: 옴니채널 고객 데이터 통합
#   - 상황: 오프라인 매장 데이터와 온라인 행동 데이터가 분리되어 어트리뷰션이 불투명
#   - 개입: 고객 식별자 매칭 및 데이터 흐름 정합성 확보, 단일 고객 뷰(Single Customer View) 구축
#   - 성과: 채널 간 기여도 명확화로 미리보기 캠페인에서 CPA 감소, 다중 채널 매출 증가
#
# 5) 데이터 품질을 높이는 실무 로드맵(간단 버전)
# - 1단계: 목표와 필수 데이터 정의
#   - 마케팅 KPI와 연결되는 필드(리드 속성, 이벤트, 구매 이력, 캠페인 매핑)를 확정
# - 2단계: 데이터 수집 규칙과 포맷 표준화
#   - 필수 필드 정의, 형식(날짜, 전화번호, 이메일 형식 등) 및 코딩 체계(카테고리 코드) 표준화
# - 3단계: 중복 제거와 데이터 정합성 확보
#   - 고객 식별자 매칭 로직, 중복 레코드 병합 규칙 수립
# - 4단계: 데이터 품질 모니터링 도입
#   - 데이터 품질 대시보드 구성(정확성, 완전성, 시의성, 중복률 등 KPI)
# - 5단계: 데이터 보강(Enrichment)과 검증
#   - 필요 시 신뢰 가능한 3자/제휴 데이터로 보강하되 프라이버시 준수 확인
# - 6단계: 데이터 거버넌스 및 보안
#   - 데이터 소유권, 수정 권한, 액세스 로그, 개인정보 보호 정책 정비
# - 7단계: 반복적 개선과 교육
#   - 주기적 데이터 품질 감사, 마케터·데이터 엔지니어 간 협업 강화, 교육 실시
#
# 6) 실무 팁과 체크리스트
# - 명확한 KPI와 데이터 매핑: 어떤 데이터가 어떤 마케팅 KPI를 예측하는가를 매핑
# - 데이터 카탈로그와 메타데이터 관리: 데이터 출처, 수집 시점, 업데이트 주기, 용도 표기
# - 자동화된 데이터 품질 검사 도구 활용: 파이프라인에서의 누락, 포맷 오류 경고 설정
# - 이벤트 추적의 일관성: GA4/태그 매니저, CRM 이벤트 간 이름과 매핑 통일
# - 개인정보와 프라이버시: 수집 최소화, 명시적 동의, 데이터 보존 기간 정책 준수
# - 측정 가능한 개선 목표: 분기별 데이터 품질 점수와 그것이 마케팅 ROI에 미치는 영향 추적
#
# 필요하시면 귀사의 현재 데이터 상태를 간단히 진단해 드릴 수 있습니다. 예를 들어, 어떤 데이터 소스가 있고, 어떤 마케팅 목표를 달성하고 싶은지 알려주시면, 좋은 데이터로 무엇을 먼저 개선하고 어떤 KPI를 목표로 삼을지 구체적인 실행 계획으로 정리해 드리겠습니다.
# ------------------------------------------------------------

# %% [markdown]
# **✅ 결과 확인**
#
# 같은 질문이지만 답변 톤과 관점이 완전히 다른 것을 확인하세요. 이것이 system 메시지의 위력입니다.
#
# > 💡 페르소나 사전을 dict로 둔 이유: 나중에 페르소나 추가/수정이 매우 쉽기 때문이에요. JSON 파일로 분리하면 코드 수정 없이도 페르소나만 갈아끼울 수 있습니다 (도전 과제 참고).

# %% [markdown]
# ---
#
# # Step 3. 챗봇 함수 만들기 (실무 5단계 중 3단계 - MVP)
#
# ## 3-1. 가장 단순한 형태부터
#
# 신입은 처음부터 모든 기능을 넣으려 합니다. 시니어는 **"한 번 질문 → 한 번 답변"** 부터 만들어요.
#
# 이번 단계의 목표는 **`ask("분석가", "...")` 한 줄로 답변을 받는 함수**를 만드는 것입니다.

# %%
# 챗봇 핵심 함수: 페르소나 이름과 질문을 받아 답변 반환
def ask(persona_name: str, question: str) -> str:
    # 1. 페르소나 이름으로 system 메시지 조회
    system_message = PERSONAS[persona_name]

    # 2. 체인 호출 (2교시에서 배운 prompt | llm 패턴)
    result = chain.invoke({"role": system_message, "question": question})

    # 3. AIMessage 객체에서 답변 텍스트만 꺼내서 반환
    return result.content

# %% [markdown]
# ## 3-2. 함수 테스트
#
# 만든 함수를 실제로 호출해봅시다.

# %%
# 분석가 페르소나로 질문
answer = ask("분석가", "A/B 테스트를 한 줄로 설명해주세요")
print(answer)
# Out:
# A/B 테스트는 두 버전(A와 B)을 무작위로 사용자에게 노출해 전환율 등 핵심 지표의 차이가 통계적으로 유의한지(p-값으로 검정)와 효과 크기를 신뢰구간으로 추정해 판단하는 실험 설계다.

# %% [markdown]
# **✅ 결과 확인**
#
# 분석가 톤의 한두 문장 답변이 나오면 성공!
#
# 이제 챗봇의 **두뇌 부분**은 완성되었어요. 이 함수 하나만 있으면 챗봇 로직은 끝난 거예요. 나머지는 다 입출력 처리입니다.

# %% [markdown]
# ---
#
# # Step 4. 명령어 처리 (실무 5단계 중 4단계)
#
# ## 4-1. 사용자 입력의 두 종류
#
# CLI 챗봇 사용자는 두 가지를 입력합니다.
#
# | 입력 | 의미 | 처리 방법 |
# | --- | --- | --- |
# | 일반 텍스트 | LLM에게 보낼 질문 | `ask()` 호출 |
# | `/`로 시작하는 텍스트 | 명령어 | 별도 처리 |
#
# 명령어를 처리하는 함수를 따로 만들어봅시다. 챗봇 로직(`ask`)과 명령어 로직을 분리하면 코드가 깔끔해져요.
#
# ## 4-2. 명령어 처리 함수
#
# 이 함수는 다음 명령어를 처리합니다.
#
# - `/quit`, `/exit` → 종료 신호 반환
# - `/change 마케터` → 페르소나 변경
# - `/persona` → 현재 페르소나 확인
# - `/help` → 도움말

# %%
# 명령어 처리 함수: (새로운_페르소나, 종료여부) 튜플 반환
def handle_command(user_input: str, current_persona: str):
    parts = user_input.split(maxsplit=1)   # "/change 마케터" → ["/change", "마케터"]
    cmd = parts[0]

    if cmd in ("/quit", "/exit"):
        print("👋 종료합니다.")
        return current_persona, True       # 종료 플래그 True

    if cmd == "/persona":
        print(f"🎭 현재 페르소나: {current_persona}")

    elif cmd == "/help":
        print("📖 명령어: /quit, /exit, /change <이름>, /persona, /help")

    elif cmd == "/change":                                  # 페르소나를 바꿔야 하는가
        new_name = parts[1] if len(parts) > 1 else ""
        if new_name in PERSONAS:
            print(f"✅ 페르소나가 '{new_name}'(으)로 변경되었습니다.")
            return new_name, False         # 페르소나만 변경
        else:
            print(f"❌ '{new_name}'은 등록된 페르소나가 아닙니다.")
            print(f"   사용 가능: {', '.join(PERSONAS.keys())}")

    else:
        print(f"❓ 알 수 없는 명령어: {cmd} (/help 입력)")

    return current_persona, False

# %% [markdown]
# ## 4-3. 명령어 처리 테스트
#
# 대화 루프를 만들기 전에 명령어가 잘 동작하는지 확인합시다.

# %%
# 페르소나 변경 시뮬레이션
current = "분석가"
current, _ = handle_command("/persona", current)
current, _ = handle_command("/change 마케터", current)
current, _ = handle_command("/persona", current)
current, _ = handle_command("/change 외계인", current)   # 잘못된 페르소나
current, _ = handle_command("/help", current)
# Out:
# 🎭 현재 페르소나: 분석가
# ✅ 페르소나가 '마케터'(으)로 변경되었습니다.
# 🎭 현재 페르소나: 마케터
# ❌ '외계인'은 등록된 페르소나가 아닙니다.
#    사용 가능: 분석가, 마케터, 개발자, 기획자, 디자이너
# 📖 명령어: /quit, /exit, /change <이름>, /persona, /help

# %% [markdown]
# **✅ 결과 확인**
#
# - `/persona`로 현재 페르소나 확인됨
# - `/change 마케터`로 변경됨
# - `/change 외계인` 같은 잘못된 이름은 거절됨
# - `/help`로 도움말이 출력됨
#
# 이 4가지가 모두 동작하면 명령어 처리는 완성!

# %% [markdown]
# ---
#
# # Step 5. CLI 대화 루프 (챗봇 완성!)
#
# ## 5-1. 대화 루프란?
#
# 지금까지 만든 부품은 3개입니다.
#
# ```
# PERSONAS          ← 페르소나 사전 (Step 2)
# ask()             ← 챗봇 두뇌 (Step 3)
# handle_command()  ← 명령어 처리 (Step 4)
# ```
#
# 이걸 모두 묶어서 **"입력을 기다리고 → 처리하고 → 다시 입력 기다리는"** 무한 루프를 만들면 챗봇이 완성됩니다.
#
# ## 5-2. 챗봇 실행 함수

# %%
# 챗봇 실행 함수
def run_chatbot(initial_persona: str = "분석가"):
    persona = initial_persona
    print(f"👋 페르소나 챗봇입니다. (현재: {persona})")
    print("   /help 로 명령어 보기, /quit 로 종료\n")

    while True:
        user_input = input("질문> ").strip()
        if not user_input:                       # 빈 입력은 무시
            continue

        if user_input.startswith("/"):           # 명령어 처리
            persona, should_quit = handle_command(user_input, persona)
            if should_quit:
                break
        else:                                    # 일반 질문 처리
            answer = ask(persona, user_input)
            print(f"[{persona}] {answer}\n")

# %% [markdown]
# ## 5-3. 챗봇 실행!
#
# 아래 셀을 실행하면 CLI 챗봇이 시작됩니다.
#
# > ⚠️ **Jupyter에서 `input()`은 노트북 상단에 입력창이 뜹니다.** 입력 후 Enter를 치세요.
# >
# > 종료하려면 `/quit` 또는 `/exit` 입력.

# %%
run_chatbot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 run_chatbot()
#
# NameError: name 'run_chatbot' is not defined

# %% [markdown]
# ---
#
# # Step 6. 시연 시나리오 검증 (실무 5단계 중 5단계)
#
# 가이드 문서의 **5개 시연 시나리오**를 직접 통과시켜봅시다. 위의 `run_chatbot()` 셀을 실행한 뒤 아래 입력을 순서대로 넣어보세요.
#
# ## 시나리오 체크리스트
#
# ```
# [ ] 시나리오 1: 일반 질문 → 분석가 톤 답변
#     질문> 머신러닝이 뭐예요?
#
# [ ] 시나리오 2: 페르소나 변경 후 같은 질문 → 답변 톤이 바뀜
#     질문> /change 마케터
#     질문> 머신러닝이 뭐예요?
#
# [ ] 시나리오 3: 잘못된 페르소나 → 거절
#     질문> /change 외계인
#
# [ ] 시나리오 4: 도움말/상태 조회
#     질문> /persona
#     질문> /help
#
# [ ] 시나리오 5: 정상 종료
#     질문> /quit
# ```

# %% [markdown]
# ---
#
# # Step 7. 도전 과제 (실무 확장)
#
# 기본 실습이 끝났다면, 실무에서 챗봇을 만들 때 자주 마주치는 확장 작업을 시도해보세요. **코드 난이도를 높이는 게 아니라**, 실무에서 첫 번째 챗봇 빌드 후 바로 따라오는 작업들입니다.
#
# ## 🎯 과제 1: 대화 로그 저장 (실무 빈도 ★★★★★)
#
# 운영 환경에서는 사용자가 무엇을 묻고 챗봇이 무엇을 답했는지 **반드시** 로그로 남깁니다. 디버깅·품질 개선·법적 대응 모든 면에서 필요해요.
#
# **요구사항**
# - 챗봇이 종료될 때 `chat_log.txt` 파일에 대화 내용 저장
# - 형식: `[시각] [페르소나] 질문 → 답변`
#
# **힌트**
# ```python
# from datetime import datetime
# log = []   # 대화 누적 리스트
# log.append(f"[{datetime.now().strftime('%H:%M:%S')}] [{persona}] {user_input} → {answer}")
# # 종료 시:
# with open("chat_log.txt", "w", encoding="utf-8") as f:
#     f.write("\n".join(log))
# ```
#
# ---
#
# ## 🎯 과제 2: 페르소나별 temperature 다르게 설정 (실무 빈도 ★★★★☆)
#
# 1교시에서 배웠죠. `temperature`는 페르소나의 성격과도 연결됩니다.
#
# - **분석가**: `temperature=0` (정확하고 일관된 답변)
# - **디자이너**: `temperature=0.8` (창의적이고 다양한 답변)
#
# **요구사항**
# - `PERSONAS` 사전 구조를 `{name: {"system": ..., "temperature": ...}}` 형태로 확장
# - `ask()` 함수에서 페르소나별 `temperature`로 호출
# - **힌트**: `ChatOpenAI(model=..., temperature=...)`을 페르소나마다 새로 만들거나, `.bind(temperature=...)`을 사용
#
# ---
#
# ## 🎯 과제 3: 페르소나를 JSON 파일로 분리 (실무 빈도 ★★★★☆)
#
# 실무에서는 페르소나가 자주 추가·수정됩니다. 코드 안에 박혀 있으면 매번 코드를 고쳐야 해요. **외부 파일로 분리하면 비개발자도 페르소나를 편집할 수 있습니다.**
#
# **요구사항**
# - `personas.json` 파일에 페르소나 정의 저장
# - 챗봇 시작 시 JSON을 읽어와 사용
#
# **힌트**
# ```python
# import json
# with open("personas.json", encoding="utf-8") as f:
#     PERSONAS = json.load(f)
# ```
#
# ---
#
# ## 🎯 과제 4: `/list` 명령어 추가 (실무 빈도 ★★★☆☆)
#
# 사용자가 어떤 페르소나가 있는지 매번 기억할 수 없어요. 목록 조회 명령어를 추가하세요.
#
# **요구사항**
# - `/list` 입력 시 페르소나 이름과 한 줄 소개 출력
# - 예: `- 분석가: 수치와 근거 기반 답변`
#
# ---
#
# ## 🎯 과제 5 (선택): max_tokens로 답변 길이 제어 (실무 빈도 ★★★☆☆)
#
# 1교시에서 배운 `max_tokens` 파라미터를 적용해보세요. 토큰 폭주 방지와 비용 관리에 핵심입니다.
#
# **요구사항**
# - 모든 답변을 200 토큰 이내로 제한
# - **힌트**: `ChatOpenAI(model="gpt-4o-mini", temperature=0.3, max_tokens=200)`
#
# ---
#
# > 💡 **5개 모두 할 필요 없습니다.** 본인이 실무에서 가장 가깝다고 느끼는 1-2개만 시도해보세요. 시간이 남으면 추가로 도전!

# %% [markdown]
# ---
#
#
# ### 실무 사고법
# - 챗봇 구축 5단계: **요구사항 → 페르소나 → MVP → 인터랙션 → 검증**
# - 가장 단순한 형태(MVP)부터 만들고 단계적으로 확장
# - 로직과 UI는 분리
#
# ### 코드 패턴
# - `prompt | llm` LCEL 체인을 함수로 감싸 재사용
# - 페르소나를 사전(dict)으로 관리
# - 명령어 분기를 별도 함수로 분리
# - CLI 입력 루프 (`while True` + `input()`)
