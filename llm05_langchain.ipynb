# %% [markdown]
# ##  2. LangChain 소개
# ### 🔹 LangChain이란?
#
# <img src ="image/LangChain.png" width="500">
#
# LangChain은 **대규모 언어모델(LLM)** 을 더 쉽게 활용할 수 있도록 도와주는 **프레임워크**입니다.
#
# 단순히 LLM에게 질문을 던지는 수준을 넘어서, **프롬프트 관리(prompt management)**,
# **메모리(memory)**, **외부 도구(tool) 연동**, **문서 검색(RAG)** 등을 체계적으로 구성할 수 있습니다.

# %% [markdown]
# 예를 들어, 우리가 ChatGPT 같은 LLM을 사용할 때
# 단순히 모델 하나만으로 뛰어난 답변이 만들어지는 것은 아닙니다.
#
# 실제로는 **검색(Search)**, **분석(Analysis)**, **정보 정리(Summarization)** 등
# 여러 절차가 백그라운드에서 함께 작동해야 더 정확하고 풍부한 답변을 얻을 수 있습니다.
#
# LangChain은 이러한 여러 단계를 **하나의 체계적인 구조로 묶어주는 프레임워크**입니다.
# 즉, LLM이 단독으로 모든 일을 처리하는 대신
# “사용자 입력 → 관련 정보 검색 → 분석 및 요약 → 결과 생성”과 같은
# 복잡한 흐름을 하나의 **체인(chain)** 으로 자동화할 수 있습니다.
#
# <img src="image/chatgpt.jpg" width="600">
#
# 예를 들어, 사용자가 “3박 4일, 30만 원 예산, 맛집 중심의 서울 여행”을 요청하면,
# LangChain은 내부적으로 다음과 같은 과정을 수행합니다.
#
# > 입력 분석 → 예산과 일정 파악 → 추천 장소 검색 → 일정표 생성 → 자연스러운 문장으로 요약
#
# 이처럼 LangChain은 단순한 대화 요청을 넘어 **검색, 분석, 조합, 요약** 등의 단계를 유기적으로 연결해
# LLM이 더 똑똑하게 작동하도록 돕습니다.

# %% [markdown]
# 또한 LangChain은 **LCEL (LangChain Expression Language)** 이라는 표현 언어를 통해
# 이러한 여러 단계(components)를 **직관적으로 연결**할 수 있게 해줍니다.
# 즉, “LLM → 요약기 → 출력 포맷터”처럼 **함수형 파이프라인**을 선언적으로 작성할 수 있어
# 확장성과 유지보수성이 뛰어납니다.
#
# LCEL 예시:
# ```text
# 사용자입력
#   | 분석기(요청에서 날짜·예산·키워드 추출)
#   | 검색기(분석 결과를 바탕으로 추천 장소 탐색)
#   | 일정생성기(추천 장소로 일자별 일정 구성)
#   | 요약기(자연스러운 문장으로 결과 정리)
#   | 출력
# ```
#
# 이처럼 LCEL은 각 단계를 함수처럼 “연결(pipe)”하여 데이터가 흘러가는 경로를 선언적으로 표현합니다.
# 복잡한 제어문 없이 “입력 → 처리 → 출력” 구조를 직관적으로 구성할 수 있어,
# 체인 전체의 논리 흐름을 한눈에 파악할 수 있습니다.

# %%
#!uv add langchain langchain_openai openai langchain_google_genai

# %% [markdown]
# ##  직접 prompt
#
# | 구분       | `invoke()`       | `generate()`                 |
# | -------- | ---------------- | ---------------------------- |
# | 입력       | 하나               | 여러 개 (batch)                 |
# | 반환       | `AIMessage` (단일) | `LLMResult` (배치+여러 결과 포함)    |
# | 사용 난이도   | 쉽다 (고수준 API)     | 어렵다 (저수준 API)                |
# | 대표 사용 사례 | 간단한 질문/응답        | 벤치마킹, 여러 쿼리 동시에 실행, n개 샘플 생성 |

# %%
#from langchain.chat_models import ChatOpenAI (이전버전)
from langchain_openai import ChatOpenAI
from langchain_core.messages import SystemMessage,HumanMessage,AIMessage


# gpt = ChatOpenAI(model="gpt-4o-mini",temperature=0)
# response = gpt.invoke( [HumanMessage(content="인공지능에 대해 말해줘")] )
# print(response.content )

gpt= ChatOpenAI(model="gpt-4o-mini", temperature=0)
response = gpt.invoke("인공지능에 대해 설명해줘")# 환경변수에 있는값 자동으로 읽어옴
print(response.content )
# Out:
# 인공지능(AI, Artificial Intelligence)은 컴퓨터 시스템이나 기계가 인간의 지능을 모방하여 학습, 추론, 문제 해결, 이해, 언어 처리 등의 작업을 수행할 수 있도록 하는 기술입니다. 인공지능은 여러 분야에서 활용되며, 크게 두 가지로 나눌 수 있습니다.
#
# 1. **약한 인공지능(Weak AI)**: 특정 작업을 수행하도록 설계된 인공지능으로, 예를 들어 음성 인식, 이미지 인식, 추천 시스템 등이 있습니다. 이러한 시스템은 특정 문제를 해결하는 데 특화되어 있으며, 일반적인 지능을 갖추고 있지 않습니다.
#
# 2. **강한 인공지능(Strong AI)**: 인간과 유사한 수준의 지능을 갖춘 인공지능으로, 다양한 문제를 이해하고 해결할 수 있는 능력을 지니고 있습니다. 현재로서는 강한 인공지능은 이론적인 개념에 가까우며, 실제로 구현된 사례는 없습니다.
#
# 인공지능의 주요 기술로는 머신러닝(Machine Learning), 딥러닝(Deep Learning), 자연어 처리(Natural Language Processing), 컴퓨터 비전(Computer Vision) 등이 있습니다. 머신러닝은 데이터에서 패턴을 학습하여 예측이나 결정을 내리는 기술이며, 딥러닝은 인공신경망을 활용한 머신러닝의 한 분야입니다.
#
# 인공지능은 의료, 금융, 제조업, 자율주행차, 고객 서비스 등 다양한 분야에서 혁신을 가져오고 있으며, 앞으로의 발전이 기대되는 분야입니다. 그러나 윤리적 문제, 일자리 대체, 개인정보 보호 등의 이슈도 함께 논의되고 있습니다.

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.messages import HumanMessage


# gpt = ChatGoogleGenerativeAI(model="gemini-2.5-flash",temperature=0)
# response = gpt.invoke([HumanMessage(content="인공지능에 대해 말해줘")] )
# print(response.content)

gpt= ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=0)
response = gpt.invoke("인공지능에 대해 설명해줘")# 환경변수에 있는값 자동으로 읽어옴
print(response.content)
# Out:
# 인공지능(AI, Artificial Intelligence)은 **컴퓨터 시스템이 인간의 지능적인 작업을 모방하고 수행하도록 만드는 기술**을 말합니다. 쉽게 말해, 기계가 사람처럼 생각하고, 학습하고, 문제를 해결하고, 의사결정을 내리는 능력을 갖추도록 하는 것이죠.
#
# ### 인공지능의 핵심 개념
#
# 1.  **학습 (Learning):** AI는 데이터를 통해 학습합니다. 특정 패턴이나 규칙을 스스로 찾아내고, 이를 바탕으로 미래를 예측하거나 새로운 결정을 내립니다.
#     *   **머신러닝 (Machine Learning):** AI의 한 분야로, 명시적으로 프로그래밍하지 않고도 컴퓨터가 데이터로부터 학습할 수 있도록 하는 기술입니다.
#     *   **딥러닝 (Deep Learning):** 머신러닝의 한 종류로, 인간 뇌의 신경망 구조를 모방한 '인공신경망'을 사용하여 복잡한 패턴을 학습하고 인식하는 데 탁월한 성능을 보입니다. 이미지 인식, 음성 인식, 자연어 처리 등에서 혁혁한 성과를 내고 있습니다.
#
# 2.  **추론 (Reasoning):** 학습한 지식과 정보를 바탕으로 논리적인 결론을 도출합니다.
#
# 3.  **문제 해결 (Problem Solving):** 주어진 목표를 달성하기 위한 최적의 방법을 찾아냅니다.
#
# 4.  **지각 (Perception):** 카메라나 마이크 같은 센서를 통해 외부 환경을 인식하고 이해합니다. (예: 이미지 인식, 음성 인식)
#
# 5.  **자연어 처리 (Natural Language Processing, NLP):** 인간의 언어를 이해하고 생성하며, 번역하거나 요약하는 등의 작업을 수행합니다.
#
# ### 인공지능의 종류
#
# 인공지능은 그 능력 수준에 따라 크게 세 가지로 나눌 수 있습니다.
#
# 1.  **약인공지능 (Narrow AI / Weak AI):**
#     *   현재 우리가 접하는 대부분의 AI가 여기에 해당합니다.
#     *   특정하고 제한된 한 가지 작업만을 수행하도록 설계되었습니다.
#     *   예: 음성 비서(Siri, 빅스비), 바둑 AI(알파고), 추천 시스템(넷플릭스, 유튜브), 자율주행 자동차, 스팸 메일 필터링 등.
#     *   인간처럼 사고하거나 의식을 가지고 있지는 않습니다.
#
# 2.  **강인공지능 (General AI / Strong AI):**
#     *   아직은 이론적인 단계에 있으며, 인간처럼 다양한 지적 작업을 수행하고 학습하며, 추론하고 문제를 해결할 수 있는 능력을 가진 AI를 말합니다.
#     *   인간과 동등하거나 그 이상의 지능을 가질 것으로 예상됩니다.
#
# 3.  **초인공지능 (Super AI):**
#     *   강인공지능을 넘어, 인간의 모든 지적 능력을 훨씬 뛰어넘는 가상의 AI입니다.
#     *   SF 영화에서 자주 등장하는 개념입니다.
#
# ### 인공지능의 활용 분야 (예시)
#
# *   **음성 인식 및 비서:** 스마트폰 음성 비서, 스마트 스피커
# *   **이미지 및 영상 인식:** 얼굴 인식, 의료 영상 분석, 자율주행 자동차의 주변 환경 인식
# *   **자연어 처리:** 번역기, 챗봇, 문서 요약, 감성 분석
# *   **추천 시스템:** 온라인 쇼핑몰, OTT 서비스의 맞춤형 콘텐츠 추천
# *   **의료:** 질병 진단 보조, 신약 개발, 맞춤형 치료법 제안
# *   **금융:** 사기 탐지, 주식 시장 예측, 신용 평가
# *   **제조업:** 로봇 자동화, 품질 검사, 생산 효율 최적화
# *   **교육:** 맞춤형 학습 콘텐츠 제공, 학습 진도 관리
# *   **콘텐츠 생성:** 그림, 음악, 글 등 창작 활동 (생성형 AI)
#
# ### 인공지능의 중요성과 미래
#
# 인공지능은 우리 사회와 산업 전반에 걸쳐 혁신적인 변화를 가져오고 있으며, 앞으로 그 영향력은 더욱 커질 것입니다. 생산성 향상, 새로운 서비스 창출, 복잡한 문제 해결 등 긍정적인 측면이 많지만, 동시에 일자리 변화, 윤리적 문제, 개인 정보 보호 등 해결해야 할 과제들도 안고 있습니다.
#
# 결론적으로 인공지능은 **인간의 지능을 모방하여 다양한 작업을 수행하고, 데이터를 통해 스스로 학습하며 발전하는 컴퓨터 시스템**이라고 할 수 있습니다.

# %%
rst = gpt.invoke( "인공지능에 대해 설명해줘" )
for chunk in rst:
    print(chunk)
    #print(chunk.content, end="")

# %%
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage
gpt = ChatOpenAI(model_name="gpt-4o-mini", temperature=0.7)
messages_batch = [
    [HumanMessage(content="인공지능에 대해 간단히 알려줄래")],
    [HumanMessage(content="파이썬에 대해 간단히 알려줄래")]
]

response = gpt.generate(messages_batch, n=2)##인자수
print(response)
print(response.generations[0][0])
print(response.generations[0][1])
print( response.generations[0][0].text )#인공지능에 대해 간단히 알려줄래-1번째 답변
print( response.generations[0][1].text )#인공지능에 대해 간단히 알려줄래-2번째 답변
print('===========')
print( response.generations[1][0].text )#"파이썬에 대해 간단히 알려줄래"-1번째 답변
print( response.generations[1][1].text )#"파이썬에 대해 간단히 알려줄래"-2번째 답변
# Out:
# generations=[[ChatGeneration(text='인공지능(Artificial Intelligence, AI)은 컴퓨터 시스템이나 소프트웨어가 인간의 지능을 모방하여 학습, 추론, 문제 해결, 이해 등의 작업을 수행할 수 있도록 하는 기술입니다. 인공지능은 크게 두 가지로 나눌 수 있습니다.\n\n1. **약한 인공지능(Weak AI)**: 특정 작업을 수행하도록 설계된 시스템으로, 예를 들어 음성 인식, 이미지 인식, 게임 플레이 등 특정한 분야에서만 기능합니다. 대화형 AI인 챗봇이나 추천 시스템 등이 이에 해당합니다.\n\n2. **강한 인공지능(Strong AI)**: 인간과 유사한 수준의 지능을 가지고 다양한 작업을 수행할 수 있는 시스템을 의미합니다. 현재는 아직 개발되지 않았으며, 이론적인 개념으로 남아 있습니다.\n\n인공지능은 머신러닝(기계 학습)과 딥러닝(심층 학습) 등의 기술을 통해 발전하고 있으며, 다양한 산업에서 활용되고 있습니다. 예를 들어, 의료 진단, 자율주행차, 금융 분석, 고객 서비스 등에서 그 응용 사례를 찾아볼 수 있습니다.', generation_info={'finish_reason': 'stop', 'logprobs': None}, message=AIMessage(content='인공지능(Artificial Intelligence, AI)은 컴퓨터 시스템이나 소프트웨어가 인간의 지능을 모방하여 학습, 추론, 문제 해결, 이해 등의 작업을 수행할 수 있도록 하는 기술입니다. 인공지능은 크게 두 가지로 나눌 수 있습니다.\n\n1. **약한 인공지능(Weak AI)**: 특정 작업을 수행하도록 설계된 시스템으로, 예를 들어 음성 인식, 이미지 인식, 게임 플레이 등 특정한 분야에서만 기능합니다. 대화형 AI인 챗봇이나 추천 시스템 등이 이에 해당합니다.\n\n2. **강한 인공지능(Strong AI)**: 인간과 유사한 수준의 지능을 가지고 다양한 작업을 수행할 수 있는 시스템을 의미합니다. 현재는 아직 개발되지 않았으며, 이론적인 개념으로 남아 있습니다.\n\n인공지능은 머신러닝(기계 학습)과 딥러닝(심층 학습) 등의 기술을 통해 발전하고 있으며, 다양한 산업에서 활용되고 있습니다. 예를 들어, 의료 진단, 자율주행차, 금융 분석, 고객 서비스 등에서 그 응용 사례를 찾아볼 수 있습니다.', additional_kwargs={'refusal': None}, response_metadata={'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a08d31-9da6-7a92-b79d-779dd8fd84bb-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 18, 'output_tokens': 497, 'total_tokens': 515, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})), ChatGeneration(text='인공지능(AI)은 컴퓨터 시스템이나 소프트웨어가 인간의 지능을 모방하여 학습, 문제 해결, 의사 결정 등을 수행할 수 있도록 하는 기술입니다. AI는 주로 두 가지 유형으로 나눌 수 있습니다.\n\n1. **약한 인공지능(Weak AI)**: 특정 작업을 수행하도록 설계된 AI로, 예를 들어 음성 인식, 이미지 인식, 챗봇 등이 있습니다. 이들은 특정 분야에서만 기능하며, 일반적인 지능을 갖추고 있지 않습니다.\n\n2. **강한 인공지능(Strong AI)**: 인간과 유사한 수준의 일반적인 지능을 갖춘 AI로, 다양한 작업을 수행할 수 있습니다. 현재는 이론적인 개념이며, 실제로 구현된 사례는 없습니다.\n\nAI는 머신러닝, 딥러닝, 자연어 처리(NLP), 로봇 공학 등 다양한 기술을 포함하고 있으며, 의료, 금융, 자동차, 엔터테인먼트 등 여러 분야에서 활용되고 있습니다. AI의 발전은 우리 생활을 변화시키고 있으며, 윤리적 문제와 함께 사회적 논의도 필요합니다.', generation_info={'finish_reason': 'stop', 'logprobs': None}, message=AIMessage(content='인공지능(AI)은 컴퓨터 시스템이나 소프트웨어가 인간의 지능을 모방하여 학습, 문제 해결, 의사 결정 등을 수행할 수 있도록 하는 기술입니다. AI는 주로 두 가지 유형으로 나눌 수 있습니다.\n\n1. **약한 인공지능(Weak AI)**: 특정 작업을 수행하도록 설계된 AI로, 예를 들어 음성 인식, 이미지 인식, 챗봇 등이 있습니다. 이들은 특정 분야에서만 기능하며, 일반적인 지능을 갖추고 있지 않습니다.\n\n2. **강한 인공지능(Strong AI)**: 인간과 유사한 수준의 일반적인 지능을 갖춘 AI로, 다양한 작업을 수행할 수 있습니다. 현재는 이론적인 개념이며, 실제로 구현된 사례는 없습니다.\n\nAI는 머신러닝, 딥러닝, 자연어 처리(NLP), 로봇 공학 등 다양한 기술을 포함하고 있으며, 의료, 금융, 자동차, 엔터테인먼트 등 여러 분야에서 활용되고 있습니다. AI의 발전은 우리 생활을 변화시키고 있으며, 윤리적 문제와 함께 사회적 논의도 필요합니다.', additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a08d31-9da6-7a92-b79d-779dd8fd84bb-1', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 18, 'output_tokens': 497, 'total_tokens': 515, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}))], [ChatGeneration(text='물론입니다! 파이썬(Python)은 1991년 귀도 반 로섬(Guido van Rossum)에 의해 개발된 고급 프로그래밍 언어입니다. 파이썬은 다음과 같은 특징을 가지고 있습니다:\n\n1. **간결하고 읽기 쉬운 문법**: 파이썬은 코드가 간결하고 직관적이어서 초보자도 쉽게 배울 수 있습니다. 또한, 코드 가독성이 높아 유지보수가 용이합니다.\n\n2. **다양한 용도**: 웹 개발, 데이터 분석, 인공지능, 머신러닝, 자동화 스크립트, 게임 개발 등 다양한 분야에서 사용됩니다.\n\n3. **강력한 라이브러리와 프레임워크**: 파이썬은 많은 외부 라이브러리와 프레임워크를 지원합니다. 예를 들어, 웹 개발에는 Django와 Flask, 데이터 분석에는 Pandas와 NumPy, 머신러닝에는 TensorFlow와 scikit-learn 등이 있습니다.\n\n4. **크로스 플랫폼**: 파이썬은 Windows, macOS, Linux 등 다양한 운영체제에서 사용할 수 있습니다.\n\n5. **대화형 프로그래밍**: 파이썬은 대화형 셸을 제공하여 코드를 즉시 실행하고 테스트할 수 있는 환경을 제공합니다.\n\n이러한 특징 덕분에 파이썬은 초보자뿐만 아니라 전문가들 사이에서도 널리 사용되고 있습니다. 추가로 궁금한 점이 있다면 말씀해 주세요!', generation_info={'finish_reason': 'stop', 'logprobs': None}, message=AIMessage(content='물론입니다! 파이썬(Python)은 1991년 귀도 반 로섬(Guido van Rossum)에 의해 개발된 고급 프로그래밍 언어입니다. 파이썬은 다음과 같은 특징을 가지고 있습니다:\n\n1. **간결하고 읽기 쉬운 문법**: 파이썬은 코드가 간결하고 직관적이어서 초보자도 쉽게 배울 수 있습니다. 또한, 코드 가독성이 높아 유지보수가 용이합니다.\n\n2. **다양한 용도**: 웹 개발, 데이터 분석, 인공지능 ...
# text='인공지능(Artificial Intelligence, AI)은 컴퓨터 시스템이나 소프트웨어가 인간의 지능을 모방하여 학습, 추론, 문제 해결, 이해 등의 작업을 수행할 수 있도록 하는 기술입니다. 인공지능은 크게 두 가지로 나눌 수 있습니다.\n\n1. **약한 인공지능(Weak AI)**: 특정 작업을 수행하도록 설계된 시스템으로, 예를 들어 음성 인식, 이미지 인식, 게임 플레이 등 특정한 분야에서만 기능합니다. 대화형 AI인 챗봇이나 추천 시스템 등이 이에 해당합니다.\n\n2. **강한 인공지능(Strong AI)**: 인간과 유사한 수준의 지능을 가지고 다양한 작업을 수행할 수 있는 시스템을 의미합니다. 현재는 아직 개발되지 않았으며, 이론적인 개념으로 남아 있습니다.\n\n인공지능은 머신러닝(기계 학습)과 딥러닝(심층 학습) 등의 기술을 통해 발전하고 있으며, 다양한 산업에서 활용되고 있습니다. 예를 들어, 의료 진단, 자율주행차, 금융 분석, 고객 서비스 등에서 그 응용 사례를 찾아볼 수 있습니다.' generation_info={'finish_reason': 'stop', 'logprobs': None} message=AIMessage(content='인공지능(Artificial Intelligence, AI)은 컴퓨터 시스템이나 소프트웨어가 인간의 지능을 모방하여 학습, 추론, 문제 해결, 이해 등의 작업을 수행할 수 있도록 하는 기술입니다. 인공지능은 크게 두 가지로 나눌 수 있습니다.\n\n1. **약한 인공지능(Weak AI)**: 특정 작업을 수행하도록 설계된 시스템으로, 예를 들어 음성 인식, 이미지 인식, 게임 플레이 등 특정한 분야에서만 기능합니다. 대화형 AI인 챗봇이나 추천 시스템 등이 이에 해당합니다.\n\n2. **강한 인공지능(Strong AI)**: 인간과 유사한 수준의 지능을 가지고 다양한 작업을 수행할 수 있는 시스템을 의미합니다. 현재는 아직 개발되지 않았으며, 이론적인 개념으로 남아 있습니다.\n\n인공지능은 머신러닝(기계 학습)과 딥러닝(심층 학습) 등의 기술을 통해 발전하고 있으며, 다양한 산업에서 활용되고 있습니다. 예를 들어, 의료 진단, 자율주행차, 금융 분석, 고객 서비스 등에서 그 응용 사례를 찾아볼 수 있습니다.', additional_kwargs={'refusal': None}, response_metadata={'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a08d31-9da6-7a92-b79d-779dd8fd84bb-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 18, 'output_tokens': 497, 'total_tokens': 515, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})
# text='인공지능(AI)은 컴퓨터 시스템이나 소프트웨어가 인간의 지능을 모방하여 학습, 문제 해결, 의사 결정 등을 수행할 수 있도록 하는 기술입니다. AI는 주로 두 가지 유형으로 나눌 수 있습니다.\n\n1. **약한 인공지능(Weak AI)**: 특정 작업을 수행하도록 설계된 AI로, 예를 들어 음성 인식, 이미지 인식, 챗봇 등이 있습니다. 이들은 특정 분야에서만 기능하며, 일반적인 지능을 갖추고 있지 않습니다.\n\n2. **강한 인공지능(Strong AI)**: 인간과 유사한 수준의 일반적인 지능을 갖춘 AI로, 다양한 작업을 수행할 수 있습니다. 현재는 이론적인 개념이며, 실제로 구현된 사례는 없습니다.\n\nAI는 머신러닝, 딥러닝, 자연어 처리(NLP), 로봇 공학 등 다양한 기술을 포함하고 있으며, 의료, 금융, 자동차, 엔터테인먼트 등 여러 분야에서 활용되고 있습니다. AI의 발전은 우리 생활을 변화시키고 있으며, 윤리적 문제와 함께 사회적 논의도 필요합니다.' generation_info={'finish_reason': 'stop', 'logprobs': None} message=AIMessage(content='인공지능(AI)은 컴퓨터 시스템이나 소프트웨어가 인간의 지능을 모방하여 학습, 문제 해결, 의사 결정 등을 수행할 수 있도록 하는 기술입니다. AI는 주로 두 가지 유형으로 나눌 수 있습니다.\n\n1. **약한 인공지능(Weak AI)**: 특정 작업을 수행하도록 설계된 AI로, 예를 들어 음성 인식, 이미지 인식, 챗봇 등이 있습니다. 이들은 특정 분야에서만 기능하며, 일반적인 지능을 갖추고 있지 않습니다.\n\n2. **강한 인공지능(Strong AI)**: 인간과 유사한 수준의 일반적인 지능을 갖춘 AI로, 다양한 작업을 수행할 수 있습니다. 현재는 이론적인 개념이며, 실제로 구현된 사례는 없습니다.\n\nAI는 머신러닝, 딥러닝, 자연어 처리(NLP), 로봇 공학 등 다양한 기술을 포함하고 있으며, 의료, 금융, 자동차, 엔터테인먼트 등 여러 분야에서 활용되고 있습니다. AI의 발전은 우리 생활을 변화시키고 있으며, 윤리적 문제와 함께 사회적 논의도 필요합니다.', additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a08d31-9da6-7a92-b79d-779dd8fd84bb-1', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 18, 'output_tokens': 497, 'total_tokens': 515, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})
# 인공지능(Artificial Intelligence, AI)은 컴퓨터 시스템이나 소프트웨어가 인간의 지능을 모방하여 학습, 추론, 문제 해결, 이해 등의 작업을 수행할 수 있도록 하는 기술입니다. 인공지능은 크게 두 가지로 나눌 수 있습니다.
#
# 1. **약한 인공지능(Weak AI)**: 특정 작업을 수행하도록 설계된 시스템으로, 예를 들어 음성 인식, 이미지 인식, 게임 플레이 등 특정한 분야에서만 기능합니다. 대화형 AI인 챗봇이나 추천 시스템 등이 이에 해당합니다.
#
# 2. **강한 인공지능(Strong AI)**: 인간과 유사한 수준의 지능을 가지고 다양한 작업을 수행할 수 있는 시스템을 의미합니다. 현재는 아직 개발되지 않았으며, 이론적인 개념으로 남아 있습니다.
#
# 인공지능은 머신러닝(기계 학습)과 딥러닝(심층 학습) 등의 기술을 통해 발전하고 있으며, 다양한 산업에서 활용되고 있습니다. 예를 들어, 의료 진단, 자율주행차, 금융 분석, 고객 서비스 등에서 그 응용 사례를 찾아볼 수 있습니다.
# 인공지능(AI)은 컴퓨터 시스템이나 소프트웨어가 인간의 지능을 모방하여 학습, 문제 해결, 의사 결정 등을 수행할 수 있도록 하는 기술입니다. AI는 주로 두 가지 유형으로 나눌 수 있습니다.
#
# 1. **약한 인공지능(Weak AI)**: 특정 작업을 수행하도록 설계된 AI로, 예를 들어 음성 인식, 이미지 인식, 챗봇 등이 있습니다. 이들은 특정 분야에서만 기능하며, 일반적인 지능을 갖추고 있지 않습니다.
#
# 2. **강한 인공지능(Strong AI)**: 인간과 유사한 수준의 일반적인 지능을 갖춘 AI로, 다양한 작업을 수행할 수 있습니다. 현재는 이론적인 개념이며, 실제로 구현된 사례는 없습니다.
#
# AI는 머신러닝, 딥러닝, 자연어 처리(NLP), 로봇 공학 등 다양한 기술을 포함하고 있으며, 의료, 금융, 자동차, 엔터테인먼트 등 여러 분야에서 활용되고 있습니다. AI의 발전은 우리 생활을 변화시키고 있으며, 윤리적 문제와 함께 사회적 논의도 필요합니다.
# ===========
# 물론입니다! 파이썬(Python)은 1991년 귀도 반 로섬(Guido van Rossum)에 의해 개발된 고급 프로그래밍 언어입니다. 파이썬은 다음과 같은 특징을 가지고 있습니다:
#
# 1. **간결하고 읽기 쉬운 문법**: 파이썬은 코드가 간결하고 직관적이어서 초보자도 쉽게 배울 수 있습니다. 또한, 코드 가독성이 높아 유지보수가 용이합니다.
#
# 2. **다양한 용도**: 웹 개발, 데이터 분석, 인공지능, 머신러닝, 자동화 스크립트, 게임 개발 등 다양한 분야에서 사용됩니다.
#
# 3. **강력한 라이브러리와 프레임워크**: 파이썬은 많은 외부 라이브러리와 프레임워크를 지원합니다. 예를 들어, 웹 개발에는 Django와 Flask, 데이터 분석에는 Pandas와 NumPy, 머신러닝에는 TensorFlow와 scikit-learn 등이 있습니다.
#
# 4. **크로스 플랫폼**: 파이썬은 Windows, macOS, Linux 등 다양한 운영체제에서 사용할 수 있습니다.
#
# 5. **대화형 프로그래밍**: 파이썬은 대화형 셸을 제공하여 코드를 즉시 실행하고 테스트할 수 있는 환경을 제공합니다.
#
# 이러한 특징 덕분에 파이썬은 초보자뿐만 아니라 전문가들 사이에서도 널리 사용되고 있습니다. 추가로 궁금한 점이 있다면 말씀해 주세요!
# 물론입니다! 파이썬(Python)은 고급 프로그래밍 언어로, 1991년 귀도 반 로썸(Guido van Rossum)에 의해 처음 발표되었습니다. 파이썬은 다음과 같은 특징을 가지고 있습니다:
#
# 1. **쉬운 문법**: 파이썬은 읽기 쉽고 이해하기 쉬운 문법을 가지고 있어, 프로그래밍 초보자에게 적합합니다.
#
# 2. **다양한 용도**: 웹 개발, 데이터 분석, 인공지능, 머신러닝, 자동화 스크립트 등 다양한 분야에서 사용됩니다.
#
# 3. **풍부한 라이브러리**: NumPy, Pandas, Matplotlib, TensorFlow, Django 등 많은 외부 라이브러리와 프레임워크가 있어, 개발자가 필요한 기능을 쉽게 추가할 수 있습니다.
#
# 4. **플랫폼 독립적**: 윈도우, macOS, 리눅스 등 다양한 운영 체제에서 실행할 수 있습니다.
#
# 5. **객체 지향 프로그래밍**: 파이썬은 객체 지향 프로그래밍(OOP)을 지원하여, 코드의 재사용성과 유지 보수성을 높입니다.
#
# 6. **커뮤니티와 지원**: 활발한 사용자 커뮤니티가 있어, 필요한 정보를 쉽게 찾을 수 있고, 문제 해결에 도움을 받을 수 있습니다.
#
# 파이썬은 그 간결함과 유연성 덕분에 많은 개발자와 기업에서 널리 사용되고 있습니다.
# c:\lab\llm-workspace\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:566: UserWarning: Unexpected type for token usage: <class 'NoneType'>
#   warnings.warn(f"Unexpected type for token usage: {type(new_usage)}")
